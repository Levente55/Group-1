# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate

n_add_rate = idk #nuclear decay + nuclear reactions

n_cap_rate = idk

n_escape_rate = idk

def calc_n_dens_rate():
    n_dens_rate = n_add_rate + n_cap_rate + n_escape_rate
